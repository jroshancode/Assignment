# %%
#1. Discount Calculator

# %%
price = float(input("Enter product price: "))
if price > 500:
    price *= 0.9
else:
    price *= 0.95
print("Final price:", price)
# Out:
# Enter product price:  500
# Final price: 475.0

# %%
#2. Odd or Even

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number:  72
# Even

# %%
#3. Driving Eligibility

# %%
age = int(input("Enter age: "))
if age >= 18:
    print("Eligible to drive")
else:
    print("Not eligible to drive")
# Out:
# Enter age:  23
# Eligible to drive

# %%
#4. Store Timing

# %%
time = int(input("Enter time (24-hour format): "))
if 9 <= time <= 21:
    print("Store is open")
else:
    print("Store is closed")
# Out:
# Enter time (24-hour format):  11
# Store is open

# %%
#5. Pass or Fail

# %%
marks = int(input("Enter marks: "))
if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks:  83
# Pass

# %%
#6. Prime Membership

# %%
prime = input("Do you have Prime membership? (yes/no): ")
if prime.lower() == "yes":
    print("Free delivery")
else:
    print("Delivery charge: ₹50")
# Out:
# Do you have Prime membership? (yes/no):  no
# Delivery charge: ₹50

# %%
#7. Leap Year Checker

# %%
year = int(input("Enter year: "))
if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year:  2026
# Not a Leap Year

# %%
#8.Temperature Alert

# %%
temp = float(input("Enter temperature: "))
if temp > 40:
    print("Heat Alert")
elif temp < 0:
    print("Cold Alert")
else:
    print("Normal Weather")
# Out:
# Enter temperature:  22
# Normal Weather

# %%
#9. Grade Calculator

# %%
percent = float(input("Enter percentage: "))
if percent >= 90:
    print("A+")
elif percent >= 80:
    print("A")
elif percent >= 70:
    print("B")
else:
    print("C")
# Out:
# Enter percentage:  88
# A

# %%
#10. Bank Withdrawal

# %%
balance = float(input("Enter balance: "))
withdraw = float(input("Enter withdrawal amount: "))
if withdraw <= balance:
    print("Withdrawal successful")
else:
    print("Insufficient balance")
# Out:
# Enter balance:  3000
# Enter withdrawal amount:  4500
# Insufficient balance

# %%
#11. Number Comparison

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
if a > b:
    print("First number is greater")
elif a < b:
    print("First number is smaller")
else:
    print("Both numbers are equal")
# Out:
# Enter first number:  23
# Enter second number:  34
# First number is smaller

# %%
#12. Password Validator

# %%
password = input("Enter password: ")
if password == "secure123":
    print("Access granted")
else:
    print("Access denied")
# Out:
# Enter password:  secure123
# Access granted

# %%
#13. Evening Discount

# %%
time = int(input("Enter time (24-hour): "))
price = float(input("Enter price: "))
if 18 <= time <= 21:
    price *= 0.8
print("Final price:", price)
# Out:
# Enter time (24-hour):  18
# Enter price:  1000
# Final price: 800.0

# %%
#14. Eligible for Voting

# %%
citizenship = input("Enter citizenship: ")
age = int(input("Enter age: "))
if citizenship.lower() == "indian" and age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
# Enter citizenship:  Indian
# Enter age:  19
# Eligible to vote

# %%
#15. Restaurant Bill Split

# %%
people = int(input("Enter number of people: "))
bill = float(input("Enter total bill amount: "))

if people > 5:
    bill = bill * 1.15   # add 15% service charge

print("Final bill amount:", bill)
# Out:
# Enter number of people:  8
# Enter total bill amount:  2000
# Final bill amount: 2300.0

# %%
#16. Delivery Service

# %%
location = input("Enter location (urban/rural): ")
if location.lower() == "urban":
    print("Delivery available")
else:
    print("Delivery not available")
# Out:
# Enter location (urban/rural):  urban
# Delivery available

# %%
#17. BMI Calculator

# %%
weight = float(input("Enter weight (kg): "))
height = float(input("Enter height (m): "))
bmi = weight / (height ** 2)

if bmi < 18.5:
    print("Underweight")
elif bmi <= 24.9:
    print("Normal")
else:
    print("Overweight")
# Out:
# Enter weight (kg):  56
# Enter height (m):  1.65
# Normal

# %%
#18. Weekend Check

# %%
day = input("Enter day: ")
if day.lower() in ["saturday", "sunday"]:
    print("Weekend")
else:
    print("Weekday")
# Out:
# Enter day:  Tuesday
# Weekday

# %%
#19. Flight Fare Check

# %%
age = int(input("Enter passenger age: "))
fare = float(input("Enter original fare: "))

if age < 12 or age > 60:
    fare = fare * 0.5   # 50% discount

print("Final fare to be paid:", fare)
# Out:
# Enter passenger age:  30
# Enter original fare:  800
# Final fare to be paid: 800.0

# %%
#20. Electicity Bill

# %%
units = int(input("Enter units consumed: "))
if units <= 100:
    bill = units * 5
elif units <= 300:
    bill = units * 10
else:
    bill = units * 15
print("Electricity bill: ₹", bill)
# Out:
# Enter units consumed:  80
# Electricity bill: ₹ 400

# %%
num1 , num2, num3 = map(int, input("Enter three numbers separated by spaces: ").split())
if num1 >= num2 and num1 >= num3:
    largest = num1
elif num2 >= num1 and num2 >= num3:
    largest = num2
else:
    largest = num3
print("The largest number is:", largest)
# Out:
# The largest number is: 76
