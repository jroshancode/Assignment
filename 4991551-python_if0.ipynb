# %%
import pandas as pd

# %%
#question1-
price=int(input("price of the product: "))
if price>500:
  discount=price*10/100
else:
  discount=price*5/100

final_price= price-discount

print("discount applied: ",discount)
print("final price: ",final_price)
# Out:
# discount applied:  0.0
# final price:  0.0

# %%
#question2-
#Take the user's age as input.
#If the age is 18 or above, display "Eligible to drive"; otherwise, display "Not eligible to drive."
age=int(input("users age:"))
if age>=18:
  print("eligible to drive:")
else:
  print("not eligible to drive:")
# Out:
# users age:8
# not eligible to drive:

# %%
#question3-
#If the age is 18 or above, display "Eligible to drive"; otherwise, display "Not eligible to drive."
age=int(input("users age:"))
if age>=18:
  print("eligible to drive:")
else:
  print("not eligible to drive:")

# %%
#question4-
#Write a program that asks the current time (24-hour format).
#If the time is between 9 AM and 9 PM, print "Store is open"; otherwise, print "Store is closed."
time=int(input("current time:"))
if  9 <= time < 21:
    print("Store is open")
else:
    print("Store is closed")
# Out:
# Store is closed

# %%
#question5-
#Take the user's marks as input.
#If the marks are 40 or above, print "Pass"; otherwise, print "Fail."
marks=int(input("marks:"))
if marks>=40:
  print("pass")
else:
  print("fail")
# Out:
# fail

# %%
#question6-
#Write a program that asks if the user has a Prime membership.
#If the user enters "yes," offer free delivery; otherwise, charge ₹50 for delivery.
prime_membership=input("prime members? :")
if prime_membership == "yes":
  print("free delivery")
else:
  print("charge 50 for delivery")
# Out:
# prime members? :yes
# free delivery

# %%
#question7-
#take a year as input.
#Check if it is a leap year or not using an if-else statement.
year=int(input("enter the year:"))
if year % 4 == 0:
  print("leap year")
else:
  print("not a leap year")
# Out:
# enter the year:2026
# not a leap year

# %%
#question8-
#If the temperature is above 40°C, display "Heat Alert"; if it’s below 0°C, display "Cold Alert";
#otherwise, display "Normal Weather."
temperature=int(input("current temperature:"))
if temperature>40:
  print("heat alert")
  if temperature<0:
    print("cold alert")
else:
  print("normal weather")
# Out:
# current temperature:2
# normal weather

# %%
#question9-
percentage = int(input("Enter your percentage marks: "))


if percentage >= 90:
    print("Grade: A+")
elif percentage >= 80:
    print("Grade: A")
elif percentage >= 70:
    print("Grade: B")
else:
    print("Grade: C")
# Out:
# Enter your percentage marks: 56
# Grade: C

# %%
#question10-
#Take the balance in a bank account and the amount the user wants to withdraw as input. If
#the withdrawal amount is less than or equal to the balance, print "Withdrawal successful";
#otherwise, print "Insufficient balance."
balance=int(input("bank balance"))
withdrawn=int(input("amount withdrawn"))
if withdrawn <= balance:
  print("withdrawal successful")
else:
  print("insufficient balance")
# Out:
# bank balance5000
# amount withdrawn4500
# withdrawal successful

# %%
#question11-
x=int(input("first number:"))
y=int(input("second number:"))
if x > y :
    print(" first number is greater then second number")
elif x < y:
    print("first number is smaller then second number")

else:
    print("equal")
# Out:
# first number:5
# second number:6
# first number is smaller then second number

# %%
#question12-
#Ask the user to input a password.
#If it matches a predefined password (e.g., "secure123"), print "Access granted"; otherwise, print
#"Access denied."
password=input("password:")
predefined_password="secure123"
if password == predefined_password:
  print("access granted")
else:
  print("access denied")
# Out:
# password:nandini123
# access denied

# %%
#question13-
#If the current time is between 6 PM and 9 PM, apply a 20% discount on the product price
#entered by the user. Otherwise, no discount is applied.
price=int(input("price of the product:"))
time=int(input("current time:"))
if 18 <= time < 21:
  discount=price*20/100
  final_price=price-discount
  print("discount applied:",discount)
  print("final_price:",final_price)
else:
  print("no discount is applied")
# Out:
# price of the product:500
# current time:20
# discount applied: 100.0
# final_price: 400.0

# %%
#question14-
#Take the user's citizenship ("Indian" or "Other") and age as input.
#If the user is Indian and 18 or above, print "Eligible to vote"; otherwise, print "Not eligible to
#vote."
age=int(input("age of the citizen"))
citizenship=(input("indian/other"))
if age > 18:
  print("eligible to vote")
  if citizenship == "indian":
    print("eligible to vote")
else:
  print("not eligible to vote")
# Out:
# age of the citizen19
# indian/otherindian
# eligible to vote
# eligible to vote

# %%
#question15-
#Ask the user for the number of people in a group.
#If it’s greater than 5, apply a 15% service charge on the total bill amount entered by the user.
number=int(input("number of the people in a group:"))
total_bill=int(input("total bill amount:"))
if number > 5:
  charges = total_bill*15/100
  final_price=total_bill + charges
  print("service_charges:",charges)
  print("final_price:",final_price)
else:
  print("not charges:")
# Out:
# number of the people in a group:6
# total bill amount:5000
# service_charges: 750.0
# final_price: 5750.0

# %%
#question16-
#Ask for the user's delivery location (as "urban" or "rural").
#If the location is urban, display "Delivery available"; otherwise, display "Delivery not available."
location=input("delivery location:")
if location == "urban":
  print("delivery available")
elif location == "rural":
  print("delivery not available")
# Out:
# delivery location:urban
# delivery available

# %%
#question17-
#Take the user’s weight (in kg) and height (in meters) as input and calculate their BMI.
#If BMI < 18.5, display "Underweight"; 18.5–24.9, display "Normal"; otherwise, display
#"Overweight."
weight=int(input("weight:"))
height=int(input("height:"))
bmi=weight/height**2
if bmi < 18.5:
  print("underweight")
elif 18.5 <= bmi <= 24.9:
  print("normal")
else:
  print("overwight")
# Out:
# weight:46
# height:156
# underweight

# %%
#question18-
#Ask the user to input a day of the week.
#If it’s Saturday or Sunday, print "Weekend"; otherwise, print "Weekday."
day=input("day of the week:")
if day == "saturday" :
  print("weekend")
elif day == "sunday" :
  print("weekend")
else:
  print("weekday")
# Out:
# day of the week:monday
# weekday

# %%
#question19-
#Take the age of a passenger as input.
#If the passenger is below 12 or above 60, apply a 50% discount on the fare entered by the user;
#otherwise, charge the full fare.
age=int(input("age of a passenger:"))
fare=int(input("fare:"))
if age < 12 or age > 60:
  discount=fare*50/100
  final_price=fare-discount
  print("discount applied:", discount)
  print("final_price:",final_price)
else:
  print("no discount")
# Out:
# age of a passenger:18
# fare:500
# no discount

# %%
#question20-
#Ask the user for the number of electricity units consumed.
#If units are:
#Less than or equal to 100: Charge ₹5 per unit.
#Between 101 and 300: Charge ₹10 per unit.
#Above 300: Charge ₹15 per unit
unit = int(input("number of electricity units consumed:"))
if unit <= 100:
  bill = unit * 5
  print("total_bill:",bill)
elif 101 < unit <300:
  bill = unit*10
  print("total_bill:",bill)
elif unit > 300:
  bill = unit*15

  print(" total_bill:",bill)
